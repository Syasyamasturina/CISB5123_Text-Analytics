# %%
# Load the dataset

import pandas as pd

file_path = "twitter_reviews.csv"
df = pd.read_csv(file_path, encoding='latin1')

pd.set_option('display.max_colwidth', None)
print(df)
# Out:
#             Username  \
# 0           nurashrr
# 1        miyaamooree
# 2        msmeoowwlah
# 3         ChanDoenia
# 4    unknowngirl_231
# ..               ...
# 133      anisiobndct
# 134      snowtiger_0
# 135       anggroaaar
# 136   youllhave2wait
# 137      renjromance
#
#                                                                                                                                                                                                                                                                                             Content
# 0                                                                                                                                                                                                           Dua kali ldr, dua kali dicurangi. Hahh! Nasib saya memang tak baiklah kalau bab ldr nie
# 1                                                                                                                                               sometime it's hurt. sebab some people are really good at pretending. Nampak dalam chat macam ada kau sorang je tapi we'll never know sebab jauh kan
# 2    Rasa macam kau single??. Sebab lepas grad masing2 dah tanggungjawab and komitment. Dah tak boleh nak tumpu dekat kau je lagi. Sakit bila kau perlu dia, bila kau nak dekat dekat dia tapi tak dapat. Hati je kena kuat. Yang penting jujur. Kalau ada apa2 tak puas hati kita settle cara baik
# 3                                               LDR itu bukan 'true love', itu cuma simulasi jadi badut jarak jauh. Lo setia jaga komitmen, sementara dia di sana lagi 'jaga' perasaan orang lain yang lebih deket secara fisik. Cinta ga kenal jarak? Bullshit. Lo cuma investasi di hantu digital
# 4                                                                                                                                   Gagal LDR di 1,7 tahun rasanya mau gila. Sedangkan dia baik2 saja sudah mendapatkan ganti di awal minggu kita putus dan sekarang sedang merayakan cinta barunya
# ..                                                                                                                                                                                                                                                                                              ...
# 133                                                                                                                                                          lowkey think ldr only work for ppl who speak malay bcs they say jauh di mata dekat di hati but in english its out of sight out of mind
# 134                                                                                                                                                           ldr buat yg kuat2 aja sih, klo yg ga bisa mending skip dlu berat bgt soalnya. apalagi klo yg satunya ga excited. siap2 aja makan hati
# 135                                                                        Makanya jangan ldr, sulit untuk diperjuangkan. Pengalaman pribadi kalau udh hilang sparks or feel nya, apalagi ldr ga akan balik seperti dulu meski ketemuan nanti. Lebih baik sudahi saja daripada nanti jadi selingkuh
# 136                    I think in an ldr it's even more important to keep daily communication since you're not seeing each other all the time. Even a "Hey I'm busy today but we'll chat later tonight" goes a long way\n\nBut yeah I agree about the mind games, at some point I'd be reaching out
# 137                                                                                                                                                              LDR hanya untuk orang2 yang berniat dan berduit.\n\nNiat utk jadiin pacarnya prioritas dan duitnya juga prioritas buat pacarnya ??
#
# [138 rows x 2 columns]

# %%
pip install deep-translator
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: deep-translator in /home/fc69356b-75f4-4e92-aba8-8e539ea45739/.local/lib/python3.11/site-packages (1.11.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from deep-translator) (4.12.2)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from deep-translator) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
from deep_translator import GoogleTranslator


def translate_to_english(text):
    try:
        return GoogleTranslator(source='auto', target='en').translate(text)
    except:
        return text
df["translated_experience"] = df["Content"].apply(translate_to_english)

pd.set_option('display.max_colwidth', None)
print(df["translated_experience"])
# Out:
# 0                                                                                                                                                                                                                                                                             Ldr twice, cheated twice. Hah! My luck is not good in this LDR chapter
# 1                                                                                                                                                                      sometimes it's hurt. because some people are really good at pretending. It looks like you're the only one in the chat but we'll never know because you're so far away, right?
# 2      Feel like you're single??. Because after graduation, everyone has responsibility and commitment. I can't lean on you anymore. It hurts when you need him, when you want to be close to him but you can't. The heart has to be strong. The important thing is to be honest. If you are not satisfied with anything, we will settle it amicably
# 3                                                             LDR is not 'true love', it's just a simulation of being a long-distance clown. You faithfully maintain your commitments, while he is there 'looking after' the feelings of other people who are closer physically. Love knows no distance? Bullshit. You just invest in digital ghosts
# 4                                                                                                                                                    Failing to be in an LDR after 1.7 years makes me feel like I'm going crazy. Meanwhile, he is fine, he got replaced at the beginning of the week we broke up and is now celebrating his new love
#                                                                                                                                                                            ...
# 133                                                                                                                                                                                                           lowkey think ldr only work for ppl who speak malay bcs they say jauh di mata dekat di hati but in english its out of sight out of mind
# 134                                                                                                                                                                                 LDR is for those who are strong, if you can't, it's better to skip it because it's really hard. especially if the other one isn't excited. just get ready to eat
# 135                                                                                         So don't be lazy, it's hard to fight. Personal experience is that the spark or feeling has disappeared, especially since the LDR won't return to the way it was before even if we meet later. It's better to just end it than to end up having an affair
# 136                                                                     I think in an ldr it's even more important to keep daily communication since you're not seeing each other all the time. Even a "Hey I'm busy today but we'll chat later tonight" goes a long way\n\nBut yeah I agree about the mind games, at some point I'd be reaching out
# 137                                                                                                                                                                                           LDR is only for people with intentions and money.\n\nIntention to make his girlfriend a priority and his money is also a priority for his girlfriend??
# Name: translated_experience, Length: 138, dtype: object

# %%
# Convert contents to lowercase

def convert_to_lowercase(text):
    return text.lower()

df["lowercased"] = df["translated_experience"].apply(convert_to_lowercase)

pd.set_option('display.max_colwidth', None)
print(df["lowercased"])
# Out:
# 0                                                                                                                                                                                                                                                                             ldr twice, cheated twice. hah! my luck is not good in this ldr chapter
# 1                                                                                                                                                                      sometimes it's hurt. because some people are really good at pretending. it looks like you're the only one in the chat but we'll never know because you're so far away, right?
# 2      feel like you're single??. because after graduation, everyone has responsibility and commitment. i can't lean on you anymore. it hurts when you need him, when you want to be close to him but you can't. the heart has to be strong. the important thing is to be honest. if you are not satisfied with anything, we will settle it amicably
# 3                                                             ldr is not 'true love', it's just a simulation of being a long-distance clown. you faithfully maintain your commitments, while he is there 'looking after' the feelings of other people who are closer physically. love knows no distance? bullshit. you just invest in digital ghosts
# 4                                                                                                                                                    failing to be in an ldr after 1.7 years makes me feel like i'm going crazy. meanwhile, he is fine, he got replaced at the beginning of the week we broke up and is now celebrating his new love
#                                                                                                                                                                            ...
# 133                                                                                                                                                                                                           lowkey think ldr only work for ppl who speak malay bcs they say jauh di mata dekat di hati but in english its out of sight out of mind
# 134                                                                                                                                                                                 ldr is for those who are strong, if you can't, it's better to skip it because it's really hard. especially if the other one isn't excited. just get ready to eat
# 135                                                                                         so don't be lazy, it's hard to fight. personal experience is that the spark or feeling has disappeared, especially since the ldr won't return to the way it was before even if we meet later. it's better to just end it than to end up having an affair
# 136                                                                     i think in an ldr it's even more important to keep daily communication since you're not seeing each other all the time. even a "hey i'm busy today but we'll chat later tonight" goes a long way\n\nbut yeah i agree about the mind games, at some point i'd be reaching out
# 137                                                                                                                                                                                           ldr is only for people with intentions and money.\n\nintention to make his girlfriend a priority and his money is also a priority for his girlfriend??
# Name: lowercased, Length: 138, dtype: object

# %%
from bs4 import BeautifulSoup

# %%
pip install emoji
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: emoji in /home/fc69356b-75f4-4e92-aba8-8e539ea45739/.local/lib/python3.11/site-packages (2.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Removal of emojis
import emoji

# Replacing emojis with ''
def remove_emojis(text):
    return emoji.replace_emoji(text, replace='')
df["emojis_removed"] = df["lowercased"].apply(remove_emojis)

pd.set_option('display.max_colwidth', None)
print(df["emojis_removed"])
# Out:
# 0                                                                                                                                                                                                                                                                             ldr twice, cheated twice. hah! my luck is not good in this ldr chapter
# 1                                                                                                                                                                      sometimes it's hurt. because some people are really good at pretending. it looks like you're the only one in the chat but we'll never know because you're so far away, right?
# 2      feel like you're single??. because after graduation, everyone has responsibility and commitment. i can't lean on you anymore. it hurts when you need him, when you want to be close to him but you can't. the heart has to be strong. the important thing is to be honest. if you are not satisfied with anything, we will settle it amicably
# 3                                                             ldr is not 'true love', it's just a simulation of being a long-distance clown. you faithfully maintain your commitments, while he is there 'looking after' the feelings of other people who are closer physically. love knows no distance? bullshit. you just invest in digital ghosts
# 4                                                                                                                                                    failing to be in an ldr after 1.7 years makes me feel like i'm going crazy. meanwhile, he is fine, he got replaced at the beginning of the week we broke up and is now celebrating his new love
#                                                                                                                                                                            ...
# 133                                                                                                                                                                                                           lowkey think ldr only work for ppl who speak malay bcs they say jauh di mata dekat di hati but in english its out of sight out of mind
# 134                                                                                                                                                                                 ldr is for those who are strong, if you can't, it's better to skip it because it's really hard. especially if the other one isn't excited. just get ready to eat
# 135                                                                                         so don't be lazy, it's hard to fight. personal experience is that the spark or feeling has disappeared, especially since the ldr won't return to the way it was before even if we meet later. it's better to just end it than to end up having an affair
# 136                                                                     i think in an ldr it's even more important to keep daily communication since you're not seeing each other all the time. even a "hey i'm busy today but we'll chat later tonight" goes a long way\n\nbut yeah i agree about the mind games, at some point i'd be reaching out
# 137                                                                                                                                                                                           ldr is only for people with intentions and money.\n\nintention to make his girlfriend a priority and his money is also a priority for his girlfriend??
# Name: emojis_removed, Length: 138, dtype: object

# %%
import re
# Replacing slang or chat words

# Slang words dictionary and the replacement
slang_dict = { 
    "tbh": "to be honest", 
    "omg": "oh my god", 
    "lol": "laugh out loud", 
    "idk": "I don't know", 
    "brb": "be right back", 
    "btw": "by the way", 
    "imo": "in my opinion", 
    "smh": "shaking my head", 
    "fyi": "for your information", 
    "np": "no problem",
    "ikr": "I know right", 
    "asap": "as soon as possible", 
    "bff": "best friend forever", 
    "gg": "good game", 
    "hmu": "hit me up", 
    "rofl": "rolling on the floor laughing" 
}

#function to replace slang used in dataset
def replace_slang(text): 
    escaped_slang_words = [] 
    for word in slang_dict.keys(): 
        escaped_word = re.escape(word)
        escaped_slang_words.append(escaped_word)
    # Join the words using '|' 
    slang_pattern = r'\b(' + '|'.join(escaped_slang_words) + r')\b'
    
    def replace_match(match): 
        slang_word = match.group(0)  
        return slang_dict[slang_word.lower()]  
    
    replaced_text = re.sub(slang_pattern, replace_match, text, flags=re.IGNORECASE)
    return replaced_text 

 
df["slangs_replaced"] = df["emojis_removed"].apply(replace_slang)


pd.set_option('display.max_colwidth', None) 
print(df["slangs_replaced"])
# Out:
# 0                                                                                                                                                                                                                                                                             ldr twice, cheated twice. hah! my luck is not good in this ldr chapter
# 1                                                                                                                                                                      sometimes it's hurt. because some people are really good at pretending. it looks like you're the only one in the chat but we'll never know because you're so far away, right?
# 2      feel like you're single??. because after graduation, everyone has responsibility and commitment. i can't lean on you anymore. it hurts when you need him, when you want to be close to him but you can't. the heart has to be strong. the important thing is to be honest. if you are not satisfied with anything, we will settle it amicably
# 3                                                             ldr is not 'true love', it's just a simulation of being a long-distance clown. you faithfully maintain your commitments, while he is there 'looking after' the feelings of other people who are closer physically. love knows no distance? bullshit. you just invest in digital ghosts
# 4                                                                                                                                                    failing to be in an ldr after 1.7 years makes me feel like i'm going crazy. meanwhile, he is fine, he got replaced at the beginning of the week we broke up and is now celebrating his new love
#                                                                                                                                                                            ...
# 133                                                                                                                                                                                                           lowkey think ldr only work for ppl who speak malay bcs they say jauh di mata dekat di hati but in english its out of sight out of mind
# 134                                                                                                                                                                                 ldr is for those who are strong, if you can't, it's better to skip it because it's really hard. especially if the other one isn't excited. just get ready to eat
# 135                                                                                         so don't be lazy, it's hard to fight. personal experience is that the spark or feeling has disappeared, especially since the ldr won't return to the way it was before even if we meet later. it's better to just end it than to end up having an affair
# 136                                                                     i think in an ldr it's even more important to keep daily communication since you're not seeing each other all the time. even a "hey i'm busy today but we'll chat later tonight" goes a long way\n\nbut yeah i agree about the mind games, at some point i'd be reaching out
# 137                                                                                                                                                                                           ldr is only for people with intentions and money.\n\nintention to make his girlfriend a priority and his money is also a priority for his girlfriend??
# Name: slangs_replaced, Length: 138, dtype: object

# %%
# Replacing contractions

contractions_dict = { 
    "wasn't": "was not", 
    "isn't": "is not", 
    "aren't": "are not", 
    "weren't": "were not", 
    "doesn't": "does not", 
    "don't": "do not", 
    "didn't": "did not", 
    "can't": "cannot", 
    "couldn't": "could not", 
    "shouldn't": "should not", 
    "wouldn't": "would not", 
    "won't": "will not", 
    "haven't": "have not", 
    "hasn't": "has not", 
    "hadn't": "had not", 
    "i'm": "i am", 
    "you're": "you are", 
    "he's": "he is", 
    "she's": "she is", 
    "it's": "it is", 
    "we're": "we are", 
    "they're": "they are", 
    "i've": "i have", 
    "you've": "you have", 
    "we've": "we have", 
    "they've": "they have", 
    "i'd": "i would", 
    "you'd": "you would", 
    "he'd": "he would", 
    "she'd": "she would", 
    "we'd": "we would", 
    "they'd": "they would", 
    "i'll": "i will", 
    "you'll": "you will", 
    "he'll": "he will", 
    "she'll": "she will", 
    "we'll": "we will", 
    "they'll": "they will", 
    "let's": "let us", 
    "that's": "that is", 
    "who's": "who is", 
    "what's": "what is", 
    "where's": "where is", 
    "when's": "when is", 
    "why's": "why is" 
} 

escaped_contractions = []
for contraction in contractions_dict.keys(): 
    escaped_contraction = re.escape(contraction)  
    escaped_contractions.append(escaped_contraction) 

joined_contractions = "|".join(escaped_contractions)
contractions_pattern = r'\b(' + joined_contractions + r')\b' 
compiled_pattern = re.compile(contractions_pattern, flags=re.IGNORECASE) 

# Defining the contraction replacement function
def replace_contractions(text): 
    def replace_match(match):
        matched_word = match.group(0)
        lower_matched_word = matched_word.lower() 
        expanded_form = contractions_dict[lower_matched_word] 
        return expanded_form 

    expanded_text = compiled_pattern.sub(replace_match, text) 
    return expanded_text

df["contractions_replaced"] = df["slangs_replaced"].apply(replace_contractions) 
pd.set_option('display.max_colwidth', None)
print(df["contractions_replaced"])
# Out:
# 0                                                                                                                                                                                                                                                                                ldr twice, cheated twice. hah! my luck is not good in this ldr chapter
# 1                                                                                                                                                                    sometimes it is hurt. because some people are really good at pretending. it looks like you are the only one in the chat but we will never know because you are so far away, right?
# 2      feel like you are single??. because after graduation, everyone has responsibility and commitment. i cannot lean on you anymore. it hurts when you need him, when you want to be close to him but you cannot. the heart has to be strong. the important thing is to be honest. if you are not satisfied with anything, we will settle it amicably
# 3                                                               ldr is not 'true love', it is just a simulation of being a long-distance clown. you faithfully maintain your commitments, while he is there 'looking after' the feelings of other people who are closer physically. love knows no distance? bullshit. you just invest in digital ghosts
# 4                                                                                                                                                      failing to be in an ldr after 1.7 years makes me feel like i am going crazy. meanwhile, he is fine, he got replaced at the beginning of the week we broke up and is now celebrating his new love
#                                                                                                                                                                              ...
# 133                                                                                                                                                                                                              lowkey think ldr only work for ppl who speak malay bcs they say jauh di mata dekat di hati but in english its out of sight out of mind
# 134                                                                                                                                                                                ldr is for those who are strong, if you cannot, it is better to skip it because it is really hard. especially if the other one is not excited. just get ready to eat
# 135                                                                                      so do not be lazy, it is hard to fight. personal experience is that the spark or feeling has disappeared, especially since the ldr will not return to the way it was before even if we meet later. it is better to just end it than to end up having an affair
# 136                                                               i think in an ldr it is even more important to keep daily communication since you are not seeing each other all the time. even a "hey i am busy today but we will chat later tonight" goes a long way\n\nbut yeah i agree about the mind games, at some point i would be reaching out
# 137                                                                                                                                                                                              ldr is only for people with intentions and money.\n\nintention to make his girlfriend a priority and his money is also a priority for his girlfriend??
# Name: contractions_replaced, Length: 138, dtype: object

# %%
# Removing punctuations and special characters 
import string 
 
def remove_punctuation(text): 
    return text.translate(str.maketrans('', '', string.punctuation))
    
df["punctuations_removed"] = df["contractions_replaced"].apply(remove_punctuation) 
 
pd.set_option('display.max_colwidth', None) 
print(df["punctuations_removed"])
# Out:
# 0                                                                                                                                                                                                                                                                        ldr twice cheated twice hah my luck is not good in this ldr chapter
# 1                                                                                                                                                             sometimes it is hurt because some people are really good at pretending it looks like you are the only one in the chat but we will never know because you are so far away right
# 2      feel like you are single because after graduation everyone has responsibility and commitment i cannot lean on you anymore it hurts when you need him when you want to be close to him but you cannot the heart has to be strong the important thing is to be honest if you are not satisfied with anything we will settle it amicably
# 3                                                               ldr is not true love it is just a simulation of being a longdistance clown you faithfully maintain your commitments while he is there looking after the feelings of other people who are closer physically love knows no distance bullshit you just invest in digital ghosts
# 4                                                                                                                                               failing to be in an ldr after 17 years makes me feel like i am going crazy meanwhile he is fine he got replaced at the beginning of the week we broke up and is now celebrating his new love
#                                                                                                                                                                        ...
# 133                                                                                                                                                                                                   lowkey think ldr only work for ppl who speak malay bcs they say jauh di mata dekat di hati but in english its out of sight out of mind
# 134                                                                                                                                                                         ldr is for those who are strong if you cannot it is better to skip it because it is really hard especially if the other one is not excited just get ready to eat
# 135                                                                               so do not be lazy it is hard to fight personal experience is that the spark or feeling has disappeared especially since the ldr will not return to the way it was before even if we meet later it is better to just end it than to end up having an affair
# 136                                                        i think in an ldr it is even more important to keep daily communication since you are not seeing each other all the time even a hey i am busy today but we will chat later tonight goes a long way\n\nbut yeah i agree about the mind games at some point i would be reaching out
# 137                                                                                                                                                                                      ldr is only for people with intentions and money\n\nintention to make his girlfriend a priority and his money is also a priority for his girlfriend
# Name: punctuations_removed, Length: 138, dtype: object

# %%
# Remove any numbers
def remove_numbers(text): 
    return re.sub(r'\d+', '', text)  
    
df["numbers_removed"] = df["punctuations_removed"].apply(remove_numbers) 

pd.set_option('display.max_colwidth', None) 
print(df["numbers_removed"])
# Out:
# 0                                                                                                                                                                                                                                                                        ldr twice cheated twice hah my luck is not good in this ldr chapter
# 1                                                                                                                                                             sometimes it is hurt because some people are really good at pretending it looks like you are the only one in the chat but we will never know because you are so far away right
# 2      feel like you are single because after graduation everyone has responsibility and commitment i cannot lean on you anymore it hurts when you need him when you want to be close to him but you cannot the heart has to be strong the important thing is to be honest if you are not satisfied with anything we will settle it amicably
# 3                                                               ldr is not true love it is just a simulation of being a longdistance clown you faithfully maintain your commitments while he is there looking after the feelings of other people who are closer physically love knows no distance bullshit you just invest in digital ghosts
# 4                                                                                                                                                 failing to be in an ldr after  years makes me feel like i am going crazy meanwhile he is fine he got replaced at the beginning of the week we broke up and is now celebrating his new love
#                                                                                                                                                                        ...
# 133                                                                                                                                                                                                   lowkey think ldr only work for ppl who speak malay bcs they say jauh di mata dekat di hati but in english its out of sight out of mind
# 134                                                                                                                                                                         ldr is for those who are strong if you cannot it is better to skip it because it is really hard especially if the other one is not excited just get ready to eat
# 135                                                                               so do not be lazy it is hard to fight personal experience is that the spark or feeling has disappeared especially since the ldr will not return to the way it was before even if we meet later it is better to just end it than to end up having an affair
# 136                                                        i think in an ldr it is even more important to keep daily communication since you are not seeing each other all the time even a hey i am busy today but we will chat later tonight goes a long way\n\nbut yeah i agree about the mind games at some point i would be reaching out
# 137                                                                                                                                                                                      ldr is only for people with intentions and money\n\nintention to make his girlfriend a priority and his money is also a priority for his girlfriend
# Name: numbers_removed, Length: 138, dtype: object

# %%
# Removal of HTML tags 
from bs4 import BeautifulSoup 

# extracts only the text, removing all HTML tags 
def remove_html_tags(text):
    return BeautifulSoup(text, "html.parser").get_text()

df["html_removed"] = df["numbers_removed"].apply(remove_html_tags)

# Remove newline characters
df["html_removed"] = df["html_removed"].str.replace("\n", " ")

# Display column content without truncation 
pd.set_option('display.max_colwidth', None)
print(df["html_removed"])
# Out:
# 0                                                                                                                                                                                                                                                                        ldr twice cheated twice hah my luck is not good in this ldr chapter
# 1                                                                                                                                                             sometimes it is hurt because some people are really good at pretending it looks like you are the only one in the chat but we will never know because you are so far away right
# 2      feel like you are single because after graduation everyone has responsibility and commitment i cannot lean on you anymore it hurts when you need him when you want to be close to him but you cannot the heart has to be strong the important thing is to be honest if you are not satisfied with anything we will settle it amicably
# 3                                                               ldr is not true love it is just a simulation of being a longdistance clown you faithfully maintain your commitments while he is there looking after the feelings of other people who are closer physically love knows no distance bullshit you just invest in digital ghosts
# 4                                                                                                                                                 failing to be in an ldr after  years makes me feel like i am going crazy meanwhile he is fine he got replaced at the beginning of the week we broke up and is now celebrating his new love
#                                                                                                                                                                        ...
# 133                                                                                                                                                                                                   lowkey think ldr only work for ppl who speak malay bcs they say jauh di mata dekat di hati but in english its out of sight out of mind
# 134                                                                                                                                                                         ldr is for those who are strong if you cannot it is better to skip it because it is really hard especially if the other one is not excited just get ready to eat
# 135                                                                               so do not be lazy it is hard to fight personal experience is that the spark or feeling has disappeared especially since the ldr will not return to the way it was before even if we meet later it is better to just end it than to end up having an affair
# 136                                                          i think in an ldr it is even more important to keep daily communication since you are not seeing each other all the time even a hey i am busy today but we will chat later tonight goes a long way  but yeah i agree about the mind games at some point i would be reaching out
# 137                                                                                                                                                                                        ldr is only for people with intentions and money  intention to make his girlfriend a priority and his money is also a priority for his girlfriend
# Name: html_removed, Length: 138, dtype: object

# %%
pip install autocorrect
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Collecting autocorrect
#   Downloading autocorrect-2.6.1.tar.gz (622 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.8/622.8 kB 8.7 MB/s eta 0:00:000:00:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py) ... done
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622363 sha256=e4c3f566284ff58d8ec22afa0844463a0bc1ba5eaade9dbc1c3bd92ae904a5a4
#   Stored in directory: /home/fc69356b-75f4-4e92-aba8-8e539ea45739/.cache/pip/wheels/5e/90/99/807a5ad861ce5d22c3c299a11df8cba9f31524f23ae6e645cb
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Correcting spelling mistakes

from autocorrect import Speller

spell = Speller(lang='en')
protected_words = ["ldr"] # Prevent the word 'ldr' to be removed

def correct_spelling(text):
    words = text.split()
    corrected_words = []

    for word in words:
        if word.lower() in protected_words:
            corrected_words.append(word)
        else:
            corrected_words.append(spell(word))
    return " ".join(corrected_words)

df["spelling_corrected"] = df["html_removed"].apply(correct_spelling)

pd.set_option('display.max_colwidth', None)
print(df["spelling_corrected"])
# Out:
# 0                                                                                                                                                                                                                                                                        ldr twice cheated twice has my luck is not good in this ldr chapter
# 1                                                                                                                                                             sometimes it is hurt because some people are really good at pretending it looks like you are the only one in the chat but we will never know because you are so far away right
# 2      feel like you are single because after graduation everyone has responsibility and commitment i cannot lean on you anymore it hurts when you need him when you want to be close to him but you cannot the heart has to be strong the important thing is to be honest if you are not satisfied with anything we will settle it amicably
# 3                                                               ldr is not true love it is just a simulation of being a longdistance clown you faithfully maintain your commitments while he is there looking after the feelings of other people who are closer physically love knows no distance bullshit you just invest in digital ghosts
# 4                                                                                                                                                  failing to be in an ldr after years makes me feel like i am going crazy meanwhile he is fine he got replaced at the beginning of the week we broke up and is now celebrating his new love
#                                                                                                                                                                        ...
# 133                                                                                                                                                                                                     hockey think ldr only work for ppl who speak mala bcs they say math di mata desat di hat but in english its out of sight out of mind
# 134                                                                                                                                                                         ldr is for those who are strong if you cannot it is better to skip it because it is really hard especially if the other one is not excited just get ready to eat
# 135                                                                               so do not be lazy it is hard to fight personal experience is that the spark or feeling has disappeared especially since the ldr will not return to the way it was before even if we meet later it is better to just end it than to end up having an affair
# 136                                                           i think in an ldr it is even more important to keep daily communication since you are not seeing each other all the time even a hey i am busy today but we will chat later tonight goes a long way but yeah i agree about the mind games at some point i would be reaching out
# 137                                                                                                                                                                                         ldr is only for people with intentions and money intention to make his girlfriend a priority and his money is also a priority for his girlfriend
# Name: spelling_corrected, Length: 138, dtype: object

# %%
# Removing  stopwords 

import nltk 
from nltk.corpus import stopwords 
 
stop_words = set(stopwords.words('english')) 

def remove_stopwords(text): 
    words = text.split()  
    filtered_words = []  
    
    for word in words:  
        lower_word = word.lower()  
        if lower_word not in stop_words:  
            filtered_words.append(word) 
    
    return " ".join(filtered_words)  

df["stopwords_removed"] = df["spelling_corrected"].apply(remove_stopwords) 
pd.set_option('display.max_colwidth', None) 
print(df["stopwords_removed"])
# Out:
# 0                                                                                                                                               ldr twice cheated twice luck good ldr chapter
# 1                                                                                                  sometimes hurt people really good pretending looks like one chat never know far away right
# 2      feel like single graduation everyone responsibility commitment cannot lean anymore hurts need want close cannot heart strong important thing honest satisfied anything settle amicably
# 3                    ldr true love simulation longdistance clown faithfully maintain commitments looking feelings people closer physically love knows distance bullshit invest digital ghosts
# 4                                                                         failing ldr years makes feel like going crazy meanwhile fine got replaced beginning week broke celebrating new love
#                                                                                                 ...
# 133                                                                                                 hockey think ldr work ppl speak mala bcs say math di mata desat di hat english sight mind
# 134                                                                                                            ldr strong cannot better skip really hard especially one excited get ready eat
# 135                                                       lazy hard fight personal experience spark feeling disappeared especially since ldr return way even meet later better end end affair
# 136                       think ldr even important keep daily communication since seeing time even hey busy today chat later tonight goes long way yeah agree mind games point would reaching
# 137                                                                                             ldr people intentions money intention make girlfriend priority money also priority girlfriend
# Name: stopwords_removed, Length: 138, dtype: object

# %%
# Stemming

from nltk.stem import PorterStemmer 

stemmer = PorterStemmer() 

def stem_text(text): 
    if not isinstance(text, str): 
        return ""
    words = text.split() 
    stemmed_words = [stemmer.stem(word) for word in words]  
    return " ".join(stemmed_words) 
    
df["stemmed_words"] = df["stopwords_removed"].apply(stem_text) 
pd.set_option('display.max_colwidth', None) 
print(df["stemmed_words"])
# Out:
# 0                                                                                                                  ldr twice cheat twice luck good ldr chapter
# 1                                                                          sometim hurt peopl realli good pretend look like one chat never know far away right
# 2      feel like singl graduat everyon respons commit cannot lean anymor hurt need want close cannot heart strong import thing honest satisfi anyth settl amic
# 3                         ldr true love simul longdist clown faith maintain commit look feel peopl closer physic love know distanc bullshit invest digit ghost
# 4                                                              fail ldr year make feel like go crazi meanwhil fine got replac begin week broke celebr new love
#                                                                                 ...
# 133                                                                   hockey think ldr work ppl speak mala bc say math di mata desat di hat english sight mind
# 134                                                                                   ldr strong cannot better skip realli hard especi one excit get readi eat
# 135                                        lazi hard fight person experi spark feel disappear especi sinc ldr return way even meet later better end end affair
# 136            think ldr even import keep daili commun sinc see time even hey busi today chat later tonight goe long way yeah agre mind game point would reach
# 137                                                                      ldr peopl intent money intent make girlfriend prioriti money also prioriti girlfriend
# Name: stemmed_words, Length: 138, dtype: object

# %%
import nltk

# Download required resources
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/fc69356b-75f4-4e92-aba8-
# [nltk_data]     8e539ea45739/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/fc69356b-75f4-4e92-aba8-
# [nltk_data]     8e539ea45739/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/fc69356b-75f4-4e92-aba8-
# [nltk_data]     8e539ea45739/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/fc69356b-75f4-4e92-aba8-
# [nltk_data]     8e539ea45739/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Lemmatization 

from nltk.stem import WordNetLemmatizer 
from nltk.corpus import wordnet 
from nltk.tokenize import word_tokenize 
from nltk import pos_tag


lemmatizer = WordNetLemmatizer() 
 
def get_wordnet_pos(nltk_tag): 
    if nltk_tag.startswith('J'):  
        return wordnet.ADJ 
    elif nltk_tag.startswith('V'):  
        return wordnet.VERB 
    elif nltk_tag.startswith('N'):  
        return wordnet.NOUN 
    elif nltk_tag.startswith('R'):   
        return wordnet.ADV 
    else: 
        return wordnet.NOUN   
 
def lemmatize_text(text): 
    if not isinstance(text, str):  
        return "" 
 
    words = word_tokenize(text) 
    pos_tags = pos_tag(words)  
     
    lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(tag)) for word, tag in pos_tags] 

    return " ".join(lemmatized_words)   

df["lemmatized"] = df["stopwords_removed"].apply(lemmatize_text) 

pd.set_option('display.max_colwidth', None)  
print(df["lemmatized"])
# Out:
# 0                                                                                                                                                ldr twice cheat twice luck good ldr chapter
# 1                                                                                                  sometimes hurt people really good pretending look like one chat never know far away right
# 2      feel like single graduation everyone responsibility commitment can not lean anymore hurt need want close can not heart strong important thing honest satisfy anything settle amicably
# 3                          ldr true love simulation longdistance clown faithfully maintain commitment look feeling people closer physically love know distance bullshit invest digital ghost
# 4                                                                                      fail ldr year make feel like go crazy meanwhile fine get replaced begin week break celebrate new love
#                                                                                                ...
# 133                                                                                                hockey think ldr work ppl speak mala bcs say math di mata desat di hat english sight mind
# 134                                                                                                           ldr strong can not better skip really hard especially one excite get ready eat
# 135                                                          lazy hard fight personal experience spark feeling disappear especially since ldr return way even meet later good end end affair
# 136                               think ldr even important keep daily communication since see time even hey busy today chat later tonight go long way yeah agree mind game point would reach
# 137                                                                                             ldr people intention money intention make girlfriend priority money also priority girlfriend
# Name: lemmatized, Length: 138, dtype: object

# %%
df.to_csv("twitter_cleaned_data.csv", index=False)
