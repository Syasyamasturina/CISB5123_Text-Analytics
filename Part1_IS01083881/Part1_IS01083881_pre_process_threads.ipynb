# %%
import pandas as pd

# 1. Load the data
file_path = "threads_reviews.csv"
df = pd.read_csv(file_path, encoding='latin1')

pd.set_option('display.max_colwidth', None)
print(df)
# Out:
#           ï»¿Username  \
# 0        eikinashikin
# 1            amyzalia
# 2        rianmarkus94
# 3    mohdhasif_putera
# 4         ran.gga6133
# ..                ...
# 194       lei_diannee
# 195      wonkybonkins
# 196      miguel669323
# 197         ccolefree
# 198           glo.mut
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Content
# 0    Me and my husband pun ldr sebelum ni. Belajar sama2 dekat U pun kluar jarang2 and lowkey taknak orang tahu then ldr Sabah-Johor. 8years relationship, jumpa 1-2 tahun sekali. Both of us commit to our relationship. Belajar apa yang masing2 nak and suka. Both supporting - career wise, lifestyle etc. So in my context, kalau sama2 commit then fight for it. It'll be worth it. Kalau sorang je beria, you know where you stand. Now, we've been married for a year plus and just welcome our first bornð¤­
# 1                                 I pernah LDR Melaka-Vienna. Entah la dikkkkk pakwe akk time tu. Buka mata je terus video cal. Bukan sbb nak tgk muka. Dia nak feel mcm tgh live in the same house. Dia suh on je video tu. Dia mandi berak masak pakai baju pun on video on(mcm CCTV hala ke dinding je pun tapi boleh sembang), atas moto video, dia tgh keje pun video. Akk kat side sini, makan lepak dgn kawan2 pun video kena on. Eh menyampah kawan2 aku tgk. Last2 dia tido dgn gegirl lain juga kat sana dik
# 2                       Cuma POV saya ya, if awal2 sudah ada rasa mcm ini, means you blom ready for LDR commitment. Better stop it before both sides pergi lebih jauh and last2 x menjadi dan buang masa. If you really mean what u feel, LDR is not an issue or excuse.. But you feeling this way itâs just obvious you donât want it. Be true to yourself and your heart. Jangan try cari apa2 alasan to cover it just to feel better.Sorry, ini cuma pendapat saya (based on pengalaman sendiri) âï¸ðð¬
# 3                                                                                                                                                                                                                                                                                                                                                    Banyak dugaan dan cabaran, klu tak kuat baik berundur je. Sebb akan timbul banyak masalah. Jgn nanti dah jauh baru nk step back sakit dan masa tu, luka pun dalam
# 4                                                                                                                                                                                                                                                                                                                                 Kdg2, hati penat menunggu jarak. Bukan tak sayang, tapi sabar ada hadnya. Pilihan untuk lepaskan itu bukan kelemahan, tapi cara jaga diri bila cinta tak mampu bertahan dengan jarak
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# 194                                                                                                                     I myself been in a 9yrs LDR it works but a few year but it ended due to his constant cheating.. a few year was fine and we are happy i guess he gets bored or something and still donât get why he do that, we meet in person travel together twice a year..\nLDR is not for everybody.. some work some didnât but if you want to try go ahead take the risk as long as you are happy go..
# 195                                                                                                                                                                                                                                                                                                                                                                                 I had a long distance relationship for a year and a bit for moving to live with him. The long distance part was quite easy for me.
# 196                                                                                                                                                                                                                                                                                                                                                                                                                    I was on a long distance relationship for 7 years and we married 2 years ago â¤ï¸â¤ï¸â¤ï¸
# 197                                                                                                                                                                                                                                                                              Long distance relationships rarely work out. To truly get to know someone, they need to spend a lot of time together in person and not chatting on the internet with occasional long distance trips to see each other for a few days.
# 198                                                                                                                                                                                                                                                                                                                                                                                                                I wd never go for long distance, nope . What is the point if you can't meet someone, go out , .....
#
# [199 rows x 2 columns]

# %%
pip install deep-translator
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: deep-translator in /home/fc69356b-75f4-4e92-aba8-8e539ea45739/.local/lib/python3.12/site-packages (1.11.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from deep-translator) (4.14.2)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from deep-translator) (2.32.5)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/fc69356b-75f4-4e92-aba8-8e539ea45739/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fc69356b-75f4-4e92-aba8-8e539ea45739/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.

# %%
from deep_translator import GoogleTranslator

#function used to translate non-english text to english
def translate_to_english(text):
    try:
        return GoogleTranslator(source='auto', target='en').translate(text)
    except:
        return text
df["translated_experience"] = df["Content"].apply(translate_to_english)

pd.set_option('display.max_colwidth', None)
print(df["translated_experience"])
# Out:
# 0                                     Me and my husband were also older before this. Studying together near the U is also rare and lowkey, no one knows about Sabah-Johor. 8years relationship, see you once every 1-2 years. Both of us commit to our relationship. Learn what each one wants and likes. Both supporting - career wise, lifestyle etc. So in my context, if you both commit then fight for it. It'll be worth it. If someone just wants to, you know where you stand. Now, we've been married for a year plus and just welcome our first bornð¤
# 1      I had a Melaka-Vienna LDR. I don't know if it was that time. Just open your eyes and watch the cal video. Not because I want to see your face. He wants to feel like living in the same house. He's already on the video. He takes a shower, cooks, cooks and wears clothes even on video on (just like CCTV pointing to the wall but can chat), on video moto, he's not funny even on video. I'm on this side, eating and hanging out with friends, the video has to be on. I'm trashing my friends, see. Last time he slept with another girl there too
# 2                                                                                    Just my POV, if you feel like this at first, it means you're not ready for LDR commitment. Better stop it before both sides go further and last2 x become and waste time. If you really mean what you feel, LDR is not an issue or excuse.. But you feel this way itâs just obvious you donât want it. Be true to yourself and your heart. Don't try to find any excuse to cover it just to feel better. Sorry, this is just my opinion (based on my own experience) âï¸ðð¬
# 3                                                                                                                                                                                                                                                                                                             There are many guesses and challenges, if you don't have the strength, it's better to just withdraw. Because many problems will arise. Don't be too far away before you can take a step back and it will hurt and by then, the wounds will be deep
# 4                                                                                                                                                                                                                                                                                                                             Kdg2, my heart is tired of waiting for the distance. It's not that I don't love you, but patience has its limits. The choice to let go is not a weakness, but a way to take care of yourself when love cannot survive the distance
#                                                                                                                                                                                                                                                                                  ...
# 194                                                                                                                                                               I myself been in a 9yrs LDR it works but a few year but it ended due to his constant cheating.. a few year was fine and we are happy i guess he gets bored or something and still donât get why he do that, we meet in person travel together twice a year..\nLDR is not for everybody.. some work some didnât but if you want to try go ahead take the risk as long as you are happy go..
# 195                                                                                                                                                                                                                                                                                                                                                                                                                           I had a long distance relationship for a year and a bit for moving to live with him. The long distance part was quite easy for me.
# 196                                                                                                                                                                                                                                                                                                                                                                                                                                                              I was on a long distance relationship for 7 years and we married 2 years ago â¤ï¸â¤ï¸â¤ï¸
# 197                                                                                                                                                                                                                                                                                                                        Long distance relationships rarely work out. To truly get to know someone, they need to spend a lot of time together in person and not chatting on the internet with occasional long distance trips to see each other for a few days.
# 198                                                                                                                                                                                                                                                                                                                                                                                                                                                          I wd never go for long distance, nope . What is the point if you can't meet someone, go out , .....
# Name: translated_experience, Length: 199, dtype: object

# %%
#function to convert all text become lower-case letters
def convert_to_lowercase(text):
    return text.lower()

#Apply the function
df["lowercased"] = df["translated_experience"].apply(convert_to_lowercase)

#Display data
pd.set_option('display.max_colwidth', None)
print(df["lowercased"])
# Out:
# 0                                     me and my husband were also older before this. studying together near the u is also rare and lowkey, no one knows about sabah-johor. 8years relationship, see you once every 1-2 years. both of us commit to our relationship. learn what each one wants and likes. both supporting - career wise, lifestyle etc. so in my context, if you both commit then fight for it. it'll be worth it. if someone just wants to, you know where you stand. now, we've been married for a year plus and just welcome our first bornð¤
# 1      i had a melaka-vienna ldr. i don't know if it was that time. just open your eyes and watch the cal video. not because i want to see your face. he wants to feel like living in the same house. he's already on the video. he takes a shower, cooks, cooks and wears clothes even on video on (just like cctv pointing to the wall but can chat), on video moto, he's not funny even on video. i'm on this side, eating and hanging out with friends, the video has to be on. i'm trashing my friends, see. last time he slept with another girl there too
# 2                                                                                    just my pov, if you feel like this at first, it means you're not ready for ldr commitment. better stop it before both sides go further and last2 x become and waste time. if you really mean what you feel, ldr is not an issue or excuse.. but you feel this way itâs just obvious you donât want it. be true to yourself and your heart. don't try to find any excuse to cover it just to feel better. sorry, this is just my opinion (based on my own experience) âï¸ðð¬
# 3                                                                                                                                                                                                                                                                                                             there are many guesses and challenges, if you don't have the strength, it's better to just withdraw. because many problems will arise. don't be too far away before you can take a step back and it will hurt and by then, the wounds will be deep
# 4                                                                                                                                                                                                                                                                                                                             kdg2, my heart is tired of waiting for the distance. it's not that i don't love you, but patience has its limits. the choice to let go is not a weakness, but a way to take care of yourself when love cannot survive the distance
#                                                                                                                                                                                                                                                                                  ...
# 194                                                                                                                                                               i myself been in a 9yrs ldr it works but a few year but it ended due to his constant cheating.. a few year was fine and we are happy i guess he gets bored or something and still donât get why he do that, we meet in person travel together twice a year..\nldr is not for everybody.. some work some didnât but if you want to try go ahead take the risk as long as you are happy go..
# 195                                                                                                                                                                                                                                                                                                                                                                                                                           i had a long distance relationship for a year and a bit for moving to live with him. the long distance part was quite easy for me.
# 196                                                                                                                                                                                                                                                                                                                                                                                                                                                              i was on a long distance relationship for 7 years and we married 2 years ago â¤ï¸â¤ï¸â¤ï¸
# 197                                                                                                                                                                                                                                                                                                                        long distance relationships rarely work out. to truly get to know someone, they need to spend a lot of time together in person and not chatting on the internet with occasional long distance trips to see each other for a few days.
# 198                                                                                                                                                                                                                                                                                                                                                                                                                                                          i wd never go for long distance, nope . what is the point if you can't meet someone, go out , .....
# Name: lowercased, Length: 199, dtype: object

# %%
from bs4 import BeautifulSoup

# %%
pip install emoji
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: emoji in /home/fc69356b-75f4-4e92-aba8-8e539ea45739/.local/lib/python3.12/site-packages (2.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import emoji 

#4. function to remove emoji
def remove_emojis(text): 
    return emoji.replace_emoji(text, replace='') 
df["emojis_removed"] = df["lowercased"].apply(remove_emojis) 

pd.set_option('display.max_colwidth', None)
print(df["emojis_removed"])
# Out:
# 0                                     me and my husband were also older before this. studying together near the u is also rare and lowkey, no one knows about sabah-johor. 8years relationship, see you once every 1-2 years. both of us commit to our relationship. learn what each one wants and likes. both supporting - career wise, lifestyle etc. so in my context, if you both commit then fight for it. it'll be worth it. if someone just wants to, you know where you stand. now, we've been married for a year plus and just welcome our first bornð¤
# 1      i had a melaka-vienna ldr. i don't know if it was that time. just open your eyes and watch the cal video. not because i want to see your face. he wants to feel like living in the same house. he's already on the video. he takes a shower, cooks, cooks and wears clothes even on video on (just like cctv pointing to the wall but can chat), on video moto, he's not funny even on video. i'm on this side, eating and hanging out with friends, the video has to be on. i'm trashing my friends, see. last time he slept with another girl there too
# 2                                                                                    just my pov, if you feel like this at first, it means you're not ready for ldr commitment. better stop it before both sides go further and last2 x become and waste time. if you really mean what you feel, ldr is not an issue or excuse.. but you feel this way itâs just obvious you donât want it. be true to yourself and your heart. don't try to find any excuse to cover it just to feel better. sorry, this is just my opinion (based on my own experience) âï¸ðð¬
# 3                                                                                                                                                                                                                                                                                                             there are many guesses and challenges, if you don't have the strength, it's better to just withdraw. because many problems will arise. don't be too far away before you can take a step back and it will hurt and by then, the wounds will be deep
# 4                                                                                                                                                                                                                                                                                                                             kdg2, my heart is tired of waiting for the distance. it's not that i don't love you, but patience has its limits. the choice to let go is not a weakness, but a way to take care of yourself when love cannot survive the distance
#                                                                                                                                                                                                                                                                                  ...
# 194                                                                                                                                                               i myself been in a 9yrs ldr it works but a few year but it ended due to his constant cheating.. a few year was fine and we are happy i guess he gets bored or something and still donât get why he do that, we meet in person travel together twice a year..\nldr is not for everybody.. some work some didnât but if you want to try go ahead take the risk as long as you are happy go..
# 195                                                                                                                                                                                                                                                                                                                                                                                                                           i had a long distance relationship for a year and a bit for moving to live with him. the long distance part was quite easy for me.
# 196                                                                                                                                                                                                                                                                                                                                                                                                                                                              i was on a long distance relationship for 7 years and we married 2 years ago â¤ï¸â¤ï¸â¤ï¸
# 197                                                                                                                                                                                                                                                                                                                        long distance relationships rarely work out. to truly get to know someone, they need to spend a lot of time together in person and not chatting on the internet with occasional long distance trips to see each other for a few days.
# 198                                                                                                                                                                                                                                                                                                                                                                                                                                                          i wd never go for long distance, nope . what is the point if you can't meet someone, go out , .....
# Name: emojis_removed, Length: 199, dtype: object

# %%
slang_dict = { 
    "tbh": "to be honest", 
    "omg": "oh my god", 
    "lol": "laugh out loud", 
    "idk": "I don't know", 
    "brb": "be right back", 
    "btw": "by the way", 
    "imo": "in my opinion", 
    "smh": "shaking my head", 
    "fyi": "for your information", 
    "np": "no problem",
    "ikr": "I know right", 
    "asap": "as soon as possible", 
    "bff": "best friend forever", 
    "gg": "good game", 
    "hmu": "hit me up", 
    "rofl": "rolling on the floor laughing" 
}

#function to replace slang used in dataset
def replace_slang(text): 
    escaped_slang_words = [] 
    for word in slang_dict.keys(): 
        escaped_word = re.escape(word)
        escaped_slang_words.append(escaped_word)
    # Join the words using '|' 
    slang_pattern = r'\b(' + '|'.join(escaped_slang_words) + r')\b'
    
    def replace_match(match): 
        slang_word = match.group(0)  
        return slang_dict[slang_word.lower()]  
    
    replaced_text = re.sub(slang_pattern, replace_match, text, flags=re.IGNORECASE)
    return replaced_text 

 
df["slangs_replaced"] = df["emojis_removed"].apply(replace_slang)


pd.set_option('display.max_colwidth', None) 
print(df["slangs_replaced"])
# Out:
# 0                                     me and my husband were also older before this. studying together near the u is also rare and lowkey, no one knows about sabah-johor. 8years relationship, see you once every 1-2 years. both of us commit to our relationship. learn what each one wants and likes. both supporting - career wise, lifestyle etc. so in my context, if you both commit then fight for it. it'll be worth it. if someone just wants to, you know where you stand. now, we've been married for a year plus and just welcome our first bornð¤
# 1      i had a melaka-vienna ldr. i don't know if it was that time. just open your eyes and watch the cal video. not because i want to see your face. he wants to feel like living in the same house. he's already on the video. he takes a shower, cooks, cooks and wears clothes even on video on (just like cctv pointing to the wall but can chat), on video moto, he's not funny even on video. i'm on this side, eating and hanging out with friends, the video has to be on. i'm trashing my friends, see. last time he slept with another girl there too
# 2                                                                                    just my pov, if you feel like this at first, it means you're not ready for ldr commitment. better stop it before both sides go further and last2 x become and waste time. if you really mean what you feel, ldr is not an issue or excuse.. but you feel this way itâs just obvious you donât want it. be true to yourself and your heart. don't try to find any excuse to cover it just to feel better. sorry, this is just my opinion (based on my own experience) âï¸ðð¬
# 3                                                                                                                                                                                                                                                                                                             there are many guesses and challenges, if you don't have the strength, it's better to just withdraw. because many problems will arise. don't be too far away before you can take a step back and it will hurt and by then, the wounds will be deep
# 4                                                                                                                                                                                                                                                                                                                             kdg2, my heart is tired of waiting for the distance. it's not that i don't love you, but patience has its limits. the choice to let go is not a weakness, but a way to take care of yourself when love cannot survive the distance
#                                                                                                                                                                                                                                                                                  ...
# 194                                                                                                                                                               i myself been in a 9yrs ldr it works but a few year but it ended due to his constant cheating.. a few year was fine and we are happy i guess he gets bored or something and still donât get why he do that, we meet in person travel together twice a year..\nldr is not for everybody.. some work some didnât but if you want to try go ahead take the risk as long as you are happy go..
# 195                                                                                                                                                                                                                                                                                                                                                                                                                           i had a long distance relationship for a year and a bit for moving to live with him. the long distance part was quite easy for me.
# 196                                                                                                                                                                                                                                                                                                                                                                                                                                                              i was on a long distance relationship for 7 years and we married 2 years ago â¤ï¸â¤ï¸â¤ï¸
# 197                                                                                                                                                                                                                                                                                                                        long distance relationships rarely work out. to truly get to know someone, they need to spend a lot of time together in person and not chatting on the internet with occasional long distance trips to see each other for a few days.
# 198                                                                                                                                                                                                                                                                                                                                                                                                                                                          i wd never go for long distance, nope . what is the point if you can't meet someone, go out , .....
# Name: slangs_replaced, Length: 199, dtype: object

# %%
import re

contractions_dict = { 
    "wasn't": "was not", 
    "isn't": "is not", 
    "aren't": "are not", 
    "weren't": "were not", 
    "doesn't": "does not", 
    "don't": "do not", 
    "didn't": "did not", 
    "can't": "cannot", 
    "couldn't": "could not", 
    "shouldn't": "should not", 
    "wouldn't": "would not", 
    "won't": "will not", 
    "haven't": "have not", 
    "hasn't": "has not", 
    "hadn't": "had not", 
    "i'm": "i am", 
    "you're": "you are", 
    "he's": "he is", 
    "she's": "she is", 
    "it's": "it is", 
    "we're": "we are", 
    "they're": "they are", 
    "i've": "i have", 
    "you've": "you have", 
    "we've": "we have", 
    "they've": "they have", 
    "i'd": "i would", 
    "you'd": "you would", 
    "he'd": "he would", 
    "she'd": "she would", 
    "we'd": "we would", 
    "they'd": "they would", 
    "i'll": "i will",
    "you'll": "you will", 
    "he'll": "he will", 
    "she'll": "she will", 
    "we'll": "we will", 
    "they'll": "they will", 
    "let's": "let us", 
    "that's": "that is", 
    "who's": "who is", 
    "what's": "what is", 
    "where's": "where is", 
    "when's": "when is", 
    "why's": "why is" 
}

escaped_contractions = []
for contraction in contractions_dict.keys():
    escaped_contraction = re.escape(contraction)
    escaped_contractions.append(escaped_contraction)

joined_contractions = "|".join(escaped_contractions)
contractions_pattern = r'\b(' + joined_contractions + r')\b'
compiled_pattern = re.compile(contractions_pattern, flags=re.IGNORECASE)

#function used to replace contractions
def replace_contractions(text):
    def replace_match(match):
        matched_word = match.group(0)
        lower_matched_word = matched_word.lower()
        expanded_form = contractions_dict[lower_matched_word]
        return expanded_form
    expanded_text = compiled_pattern.sub(replace_match, text)

    return expanded_text

df["contractions_replaced"] = df["slangs_replaced"].apply(replace_contractions)

pd.set_option('display.max_colwidth', None)
print(df["contractions_replaced"])
# Out:
# 0                                        me and my husband were also older before this. studying together near the u is also rare and lowkey, no one knows about sabah-johor. 8years relationship, see you once every 1-2 years. both of us commit to our relationship. learn what each one wants and likes. both supporting - career wise, lifestyle etc. so in my context, if you both commit then fight for it. it'll be worth it. if someone just wants to, you know where you stand. now, we have been married for a year plus and just welcome our first bornð¤
# 1      i had a melaka-vienna ldr. i do not know if it was that time. just open your eyes and watch the cal video. not because i want to see your face. he wants to feel like living in the same house. he is already on the video. he takes a shower, cooks, cooks and wears clothes even on video on (just like cctv pointing to the wall but can chat), on video moto, he is not funny even on video. i am on this side, eating and hanging out with friends, the video has to be on. i am trashing my friends, see. last time he slept with another girl there too
# 2                                                                                       just my pov, if you feel like this at first, it means you are not ready for ldr commitment. better stop it before both sides go further and last2 x become and waste time. if you really mean what you feel, ldr is not an issue or excuse.. but you feel this way itâs just obvious you donât want it. be true to yourself and your heart. do not try to find any excuse to cover it just to feel better. sorry, this is just my opinion (based on my own experience) âï¸ðð¬
# 3                                                                                                                                                                                                                                                                                                               there are many guesses and challenges, if you do not have the strength, it is better to just withdraw. because many problems will arise. do not be too far away before you can take a step back and it will hurt and by then, the wounds will be deep
# 4                                                                                                                                                                                                                                                                                                                                kdg2, my heart is tired of waiting for the distance. it is not that i do not love you, but patience has its limits. the choice to let go is not a weakness, but a way to take care of yourself when love cannot survive the distance
#                                                                                                                                                                                                                                                                                     ...
# 194                                                                                                                                                                    i myself been in a 9yrs ldr it works but a few year but it ended due to his constant cheating.. a few year was fine and we are happy i guess he gets bored or something and still donât get why he do that, we meet in person travel together twice a year..\nldr is not for everybody.. some work some didnât but if you want to try go ahead take the risk as long as you are happy go..
# 195                                                                                                                                                                                                                                                                                                                                                                                                                                i had a long distance relationship for a year and a bit for moving to live with him. the long distance part was quite easy for me.
# 196                                                                                                                                                                                                                                                                                                                                                                                                                                                                   i was on a long distance relationship for 7 years and we married 2 years ago â¤ï¸â¤ï¸â¤ï¸
# 197                                                                                                                                                                                                                                                                                                                             long distance relationships rarely work out. to truly get to know someone, they need to spend a lot of time together in person and not chatting on the internet with occasional long distance trips to see each other for a few days.
# 198                                                                                                                                                                                                                                                                                                                                                                                                                                                              i wd never go for long distance, nope . what is the point if you cannot meet someone, go out , .....
# Name: contractions_replaced, Length: 199, dtype: object

# %%
import string

#function used to remove punctuation
def remove_punctuation(text): 
    return text.translate(str.maketrans('', '', string.punctuation))

df["punctuations_removed"] = df["contractions_replaced"].apply(remove_punctuation)
df["punctuations_removed"] = df["punctuations_removed"].apply(lambda x: re.sub(r'[^\x00-\x7F]+', '', x))

pd.set_option('display.max_colwidth', None) 
print(df["punctuations_removed"])
# Out:
# 0                                          me and my husband were also older before this studying together near the u is also rare and lowkey no one knows about sabahjohor 8years relationship see you once every 12 years both of us commit to our relationship learn what each one wants and likes both supporting  career wise lifestyle etc so in my context if you both commit then fight for it itll be worth it if someone just wants to you know where you stand now we have been married for a year plus and just welcome our first born
# 1      i had a melakavienna ldr i do not know if it was that time just open your eyes and watch the cal video not because i want to see your face he wants to feel like living in the same house he is already on the video he takes a shower cooks cooks and wears clothes even on video on just like cctv pointing to the wall but can chat on video moto he is not funny even on video i am on this side eating and hanging out with friends the video has to be on i am trashing my friends see last time he slept with another girl there too
# 2                                                                                         just my pov if you feel like this at first it means you are not ready for ldr commitment better stop it before both sides go further and last2 x become and waste time if you really mean what you feel ldr is not an issue or excuse but you feel this way its just obvious you dont want it be true to yourself and your heart do not try to find any excuse to cover it just to feel better sorry this is just my opinion based on my own experience
# 3                                                                                                                                                                                                                                                                                                 there are many guesses and challenges if you do not have the strength it is better to just withdraw because many problems will arise do not be too far away before you can take a step back and it will hurt and by then the wounds will be deep
# 4                                                                                                                                                                                                                                                                                                                  kdg2 my heart is tired of waiting for the distance it is not that i do not love you but patience has its limits the choice to let go is not a weakness but a way to take care of yourself when love cannot survive the distance
#                                                                                                                                                                                                                                                                           ...
# 194                                                                                                                                                                i myself been in a 9yrs ldr it works but a few year but it ended due to his constant cheating a few year was fine and we are happy i guess he gets bored or something and still dont get why he do that we meet in person travel together twice a year\nldr is not for everybody some work some didnt but if you want to try go ahead take the risk as long as you are happy go
# 195                                                                                                                                                                                                                                                                                                                                                                                                               i had a long distance relationship for a year and a bit for moving to live with him the long distance part was quite easy for me
# 196                                                                                                                                                                                                                                                                                                                                                                                                                                                                  i was on a long distance relationship for 7 years and we married 2 years ago
# 197                                                                                                                                                                                                                                                                                                             long distance relationships rarely work out to truly get to know someone they need to spend a lot of time together in person and not chatting on the internet with occasional long distance trips to see each other for a few days
# 198                                                                                                                                                                                                                                                                                                                                                                                                                                                    i wd never go for long distance nope  what is the point if you cannot meet someone go out
# Name: punctuations_removed, Length: 199, dtype: object

# %%
#function used to remove numbers
def remove_numbers(text):
    return re.sub(r'\d+', '', text)

df["numbers_removed"] = df["punctuations_removed"].apply(remove_numbers)

pd.set_option('display.max_colwidth', None)
print(df["numbers_removed"])
# Out:
# 0                                             me and my husband were also older before this studying together near the u is also rare and lowkey no one knows about sabahjohor years relationship see you once every  years both of us commit to our relationship learn what each one wants and likes both supporting  career wise lifestyle etc so in my context if you both commit then fight for it itll be worth it if someone just wants to you know where you stand now we have been married for a year plus and just welcome our first born
# 1      i had a melakavienna ldr i do not know if it was that time just open your eyes and watch the cal video not because i want to see your face he wants to feel like living in the same house he is already on the video he takes a shower cooks cooks and wears clothes even on video on just like cctv pointing to the wall but can chat on video moto he is not funny even on video i am on this side eating and hanging out with friends the video has to be on i am trashing my friends see last time he slept with another girl there too
# 2                                                                                          just my pov if you feel like this at first it means you are not ready for ldr commitment better stop it before both sides go further and last x become and waste time if you really mean what you feel ldr is not an issue or excuse but you feel this way its just obvious you dont want it be true to yourself and your heart do not try to find any excuse to cover it just to feel better sorry this is just my opinion based on my own experience
# 3                                                                                                                                                                                                                                                                                                 there are many guesses and challenges if you do not have the strength it is better to just withdraw because many problems will arise do not be too far away before you can take a step back and it will hurt and by then the wounds will be deep
# 4                                                                                                                                                                                                                                                                                                                   kdg my heart is tired of waiting for the distance it is not that i do not love you but patience has its limits the choice to let go is not a weakness but a way to take care of yourself when love cannot survive the distance
#                                                                                                                                                                                                                                                                           ...
# 194                                                                                                                                                                 i myself been in a yrs ldr it works but a few year but it ended due to his constant cheating a few year was fine and we are happy i guess he gets bored or something and still dont get why he do that we meet in person travel together twice a year\nldr is not for everybody some work some didnt but if you want to try go ahead take the risk as long as you are happy go
# 195                                                                                                                                                                                                                                                                                                                                                                                                               i had a long distance relationship for a year and a bit for moving to live with him the long distance part was quite easy for me
# 196                                                                                                                                                                                                                                                                                                                                                                                                                                                                    i was on a long distance relationship for  years and we married  years ago
# 197                                                                                                                                                                                                                                                                                                             long distance relationships rarely work out to truly get to know someone they need to spend a lot of time together in person and not chatting on the internet with occasional long distance trips to see each other for a few days
# 198                                                                                                                                                                                                                                                                                                                                                                                                                                                    i wd never go for long distance nope  what is the point if you cannot meet someone go out
# Name: numbers_removed, Length: 199, dtype: object

# %%
pip install autocorrect
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: autocorrect in /home/fc69356b-75f4-4e92-aba8-8e539ea45739/.local/lib/python3.12/site-packages (2.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from autocorrect import Speller

spell = Speller(lang='en')
protected_words = ["ldr"]

#function used to correct typos/spelling error
def correct_spelling(text):
    words = text.split()
    corrected_words = []

    for word in words:
        if word.lower() in protected_words:
            corrected_words.append(word)
        else:
            corrected_words.append(spell(word))
    return " ".join(corrected_words)

df["spelling_corrected"] = df["numbers_removed"].apply(correct_spelling)

pd.set_option('display.max_colwidth', None)
print(df["spelling_corrected"])
# Out:
# 0                                              me and my husband were also older before this studying together near the u is also rare and hockey no one knows about sabahjohor years relationship see you once every years both of us commit to our relationship learn what each one wants and likes both supporting career wise lifestyle etc so in my context if you both commit then fight for it till be worth it if someone just wants to you know where you stand now we have been married for a year plus and just welcome our first born
# 1      i had a melakavienna ldr i do not know if it was that time just open your eyes and watch the cal video not because i want to see your face he wants to feel like living in the same house he is already on the video he takes a shower cooks cooks and wears clothes even on video on just like ctv pointing to the wall but can chat on video moto he is not funny even on video i am on this side eating and hanging out with friends the video has to be on i am crashing my friends see last time he slept with another girl there too
# 2                                                                                          just my pov if you feel like this at first it means you are not ready for ldr commitment better stop it before both sides go further and last x become and waste time if you really mean what you feel ldr is not an issue or excuse but you feel this way its just obvious you dont want it be true to yourself and your heart do not try to find any excuse to cover it just to feel better sorry this is just my opinion based on my own experience
# 3                                                                                                                                                                                                                                                                                                there are many guesses and challenges if you do not have the strength it is better to just withdraw because many problems will arise do not be too far away before you can take a step back and it will hurt and by then the wounds will be deep
# 4                                                                                                                                                                                                                                                                                                                   kg my heart is tired of waiting for the distance it is not that i do not love you but patience has its limits the choice to let go is not a weakness but a way to take care of yourself when love cannot survive the distance
#                                                                                                                                                                                                                                                                           ...
# 194                                                                                                                                                                 i myself been in a yrs ldr it works but a few year but it ended due to his constant cheating a few year was fine and we are happy i guess he gets bored or something and still dont get why he do that we meet in person travel together twice a year ldr is not for everybody some work some didnt but if you want to try go ahead take the risk as long as you are happy go
# 195                                                                                                                                                                                                                                                                                                                                                                                                              i had a long distance relationship for a year and a bit for moving to live with him the long distance part was quite easy for me
# 196                                                                                                                                                                                                                                                                                                                                                                                                                                                                      i was on a long distance relationship for years and we married years ago
# 197                                                                                                                                                                                                                                                                                                            long distance relationships rarely work out to truly get to know someone they need to spend a lot of time together in person and not chatting on the internet with occasional long distance trips to see each other for a few days
# 198                                                                                                                                                                                                                                                                                                                                                                                                                                                      i wd never go for long distance note what is the point if you cannot meet someone go out
# Name: spelling_corrected, Length: 199, dtype: object

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

#function used to remove stopwords
def remove_stopwords(text):
    words = text.split()
    filtered_words = []

    for word in words:
        lower_word = word.lower()
        if lower_word not in stop_words:
            filtered_words.append(word)
    return " ".join(filtered_words)

df["stopwords_removed"] = df["spelling_corrected"].apply(remove_stopwords)
pd.set_option('display.max_colwidth', None)
print(df["stopwords_removed"])
# Out:
# 0             husband also older studying together near u also rare hockey one knows sabahjohor years relationship see every years us commit relationship learn one wants likes supporting career wise lifestyle etc context commit fight till worth someone wants know stand married year plus welcome first born
# 1      melakavienna ldr know time open eyes watch cal video want see face wants feel like living house already video takes shower cooks cooks wears clothes even video like ctv pointing wall chat video moto funny even video side eating hanging friends video crashing friends see last time slept another girl
# 2                                                                            pov feel like first means ready ldr commitment better stop sides go last x become waste time really mean feel ldr issue excuse feel way obvious dont want true heart try find excuse cover feel better sorry opinion based experience
# 3                                                                                                                                                                                                    many guesses challenges strength better withdraw many problems arise far away take step back hurt wounds deep
# 4                                                                                                                                                                                           kg heart tired waiting distance love patience limits choice let go weakness way take care love cannot survive distance
#                                                                                                                                                           ...
# 194                                                                                             yrs ldr works year ended due constant cheating year fine happy guess gets bored something still dont get meet person travel together twice year ldr everybody work didnt want try go ahead take risk long happy go
# 195                                                                                                                                                                                                                                  long distance relationship year bit moving live long distance part quite easy
# 196                                                                                                                                                                                                                                                             long distance relationship years married years ago
# 197                                                                                                                                                   long distance relationships rarely work truly get know someone need spend lot time together person chatting internet occasional long distance trips see days
# 198                                                                                                                                                                                                                                                    wd never go long distance note point cannot meet someone go
# Name: stopwords_removed, Length: 199, dtype: object
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/fc69356b-75f4-4e92-aba8-
# [nltk_data]     8e539ea45739/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer() 

#function used to apply stemming
def stem_text(text):
    if not isinstance(text, str):
        return ""
    words = text.split()
    stemmed_words = [stemmer.stem(word) for word in words]
    return " ".join(stemmed_words)

df["stemmed_words"] = df["stopwords_removed"].apply(stem_text)

pd.set_option('display.max_colwidth', None)
print(df["stemmed_words"])
# Out:
# 0      husband also older studi togeth near u also rare hockey one know sabahjohor year relationship see everi year us commit relationship learn one want like support career wise lifestyl etc context commit fight till worth someon want know stand marri year plu welcom first born
# 1      melakavienna ldr know time open eye watch cal video want see face want feel like live hous alreadi video take shower cook cook wear cloth even video like ctv point wall chat video moto funni even video side eat hang friend video crash friend see last time slept anoth girl
# 2                                                                  pov feel like first mean readi ldr commit better stop side go last x becom wast time realli mean feel ldr issu excus feel way obviou dont want true heart tri find excus cover feel better sorri opinion base experi
# 3                                                                                                                                                                                mani guess challeng strength better withdraw mani problem aris far away take step back hurt wound deep
# 4                                                                                                                                                                              kg heart tire wait distanc love patienc limit choic let go weak way take care love cannot surviv distanc
#                                                                                                                                              ...
# 194                                                                                yr ldr work year end due constant cheat year fine happi guess get bore someth still dont get meet person travel togeth twice year ldr everybodi work didnt want tri go ahead take risk long happi go
# 195                                                                                                                                                                                                            long distanc relationship year bit move live long distanc part quit easi
# 196                                                                                                                                                                                                                                       long distanc relationship year marri year ago
# 197                                                                                                                                        long distanc relationship rare work truli get know someon need spend lot time togeth person chat internet occasion long distanc trip see day
# 198                                                                                                                                                                                                                           wd never go long distanc note point cannot meet someon go
# Name: stemmed_words, Length: 199, dtype: object

# %%
import nltk

nltk.download('wordnet')                    
nltk.download('omw-1.4')                 
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt_tab') # For tokenization
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/fc69356b-75f4-4e92-aba8-
# [nltk_data]     8e539ea45739/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/fc69356b-75f4-4e92-aba8-
# [nltk_data]     8e539ea45739/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/fc69356b-75f4-4e92-aba8-
# [nltk_data]     8e539ea45739/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/fc69356b-75f4-4e92-aba8-
# [nltk_data]     8e539ea45739/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import wordnet 
from nltk.tokenize import word_tokenize 
from nltk import pos_tag

lemmatizer = WordNetLemmatizer()

def get_wordnet_pos(nltk_tag):
    if nltk_tag.startswith('J'):
         return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

def lemmatize_text(text):
    if not isinstance(text,str):
        return ""
    words = word_tokenize(text)
    pos_tags = pos_tag(words)

    lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(tag)) for word, tag in pos_tags]

    return " ".join(lemmatized_words) 
 
df["lemmatized"] = df["stemmed_words"].apply(lemmatize_text)

pd.set_option('display.max_colwidth', None)
print(df["lemmatized"])

# %%
df.to_csv("threads_cleaned_data.csv", index=False)
